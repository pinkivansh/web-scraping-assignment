# %%
# 4.Write a python program to scrape product name, price and discounts from https://meesho.com/bagsladies/pl/p7vbp .

import requests
from bs4 import BeautifulSoup 
import pandas as pd

url='https://meesho.com/bags-ladies/pl/p7vbp'
page=requests.get(url)
soup=BeautifulSoup(page.content)
product_name=[]
for i in soup.find_all('p', class_="Text__StyledText-sc-oo0kvp-0 bWSOET NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS"):
    product_name.append(i.text)
    
#product_name
prices=[]
for j in soup.find_all('h5', class_="Text__StyledText-sc-oo0kvp-0 hiHdyy"):
    prices.append(j.text)
    
#prices
discount_prices=[]
for k in soup.find_all('p', class_="Text__StyledText-sc-oo0kvp-0 fCJVtz NewProductCard__DiscountTextParagraph-sc-j0e7tu-16 kmYsnm NewProductCard__DiscountTextParagraph-sc-j0e7tu-16 kmYsnm"):
    discount_prices.append(k.text)
#discount_prices


df=pd.DataFrame({'product Name': product_name, 'Price' :prices, 'Discount Prices': discount_prices})
df
# Out:
#                                          product Name Price  \
# 0      MGPLifestyle MGP Creation Hand Made Basket Bag  ₹199
# 1                                               Red-0  ₹216
# 2                           Ladies Top Handle Handbag  ₹259
# 3                                       Women handbag  ₹985
# 4                              Women's Handbag (Grey)  ₹235
# 5                                             Handbag  ₹216
# 6      MGPLifestyle MGP Creation Hand Made Basket Bag  ₹197
# 7      MGPLifestyle MGP Creation Hand Made Basket Bag  ₹198
# 8   Pepino Trending Handbag Collection Women Offic...  ₹235
# 9      MGPLifestyle MGP Creation Hand Made Basket Bag  ₹199
# 10     MGPLifestyle MGP Creation Hand Made Basket Bag  ₹185
# 11     MGPLifestyle MGP Creation Hand Made Basket Bag  ₹179
# 12                                    amazing handbag  ₹193
# 13     MGPLifestyle MGP Creation Hand Made Basket Bag  ₹199
# 14                                   GLOSSY HAND BAG   ₹175
# 15     MGPLifestyle MGP Creation Hand Made Basket Bag  ₹199
# 16                                   feminine fashion  ₹545
# 17     MGPLifestyle MGP Creation Hand Made Basket Bag  ₹199
# 18                    Graceful Stylish Women Handbags  ₹217
# 19     MGPLifestyle MGP Creation Hand Made Basket Bag  ₹199
#
#                Discount Prices
# 0    ₹85 discount on 1st order
# 1    ₹92 discount on 1st order
# 2   ₹100 discount on 1st order
# 3   ₹100 discount on 1st order
# 4   ₹100 discount on 1st order
# 5    ₹92 discount on 1st order
# 6    ₹84 discount on 1st order
# 7    ₹84 discount on 1st order
# 8   ₹100 discount on 1st order
# 9    ₹85 discount on 1st order
# 10   ₹79 discount on 1st order
# 11   ₹76 discount on 1st order
# 12   ₹82 discount on 1st order
# 13   ₹84 discount on 1st order
# 14   ₹75 discount on 1st order
# 15   ₹85 discount on 1st order
# 16  ₹100 discount on 1st order
# 17   ₹85 discount on 1st order
# 18   ₹93 discount on 1st order
# 19   ₹85 discount on 1st order
